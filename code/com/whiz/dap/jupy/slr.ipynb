# %% [markdown]
# # Simple Line Reression:

# %% [markdown]
# Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Generate random input data to train on

# %%
observations = 1000
xs=np.random.uniform(low=-10, high=10, size=(observations, 1))
zs=np.random.uniform(low=-10, high=10, size=(observations, 1))

inputs = np.column_stack((xs,zs))
print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# Create the tragets

# %%
noise = np.random.uniform(-1,1,size=(observations, 1))

targets = 2*xs - 3*zs + 5 + noise

print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# Plot the traning data

# %%
targets = targets.reshape(observations,)
print(targets.shape)
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot(xs,zs,targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targetes')
plt.show()

targets = targets.reshape(observations,1)
# Out:
# (1000,)

# %%
init_range = 0.1
weights = np.random.uniform(-init_range,init_range , size = (2,1))
biases = np.random.uniform(-init_range,init_range )
print(weights)
print(biases)
# Out:
# [[0.03503878]
#  [0.07048176]]
# -0.06470006825868775

# %% [markdown]
# set a leanrning rate

# %%
learning_rate = 0.02

# %% [markdown]
# Train the model

# %%
for i in range(100):
    outputs = np.dot(inputs,weights) + biases
    deltas = outputs - targets
    
    loss = np.sum(deltas**2) /2 /observations
    
    
    print(loss)
    
    deltas_scaled = deltas / observations
    
    
    weights = weights-learning_rate * np.dot(inputs.T,deltas_scaled)
    biases = biases  - learning_rate * np.sum(deltas_scaled)
# Out:
# 0.39175327262436976
# 0.38292888189156965
# 0.374453540424156
# 0.3663134415590566
# 0.35849532475652274
# 0.35098645399819295
# 0.3437745970396185
# 0.33684800548345983
# 0.3301953956408853
# 0.3238059301500022
# 0.31766920032136853
# 0.3117752091818315
# 0.3061143551890666
# 0.30067741659028946
# 0.2954555363996584
# 0.2904402079698987
# 0.28562326113464026
# 0.2809968488988985
# 0.27655343465601046
# 0.27228577991020847
# 0.2681869324848268
# 0.26425021519693365
# 0.2604692149799383
# 0.25683777243645645
# 0.2533499718044079
# 0.2500001313200105
# 0.2467827939619644
# 0.24369271856174998
# 0.24072487126555894
# 0.2378744173339504
# 0.2351367132658705
# 0.23250729923420685
# 0.229981891820557
# 0.22755637703737047
# 0.22522680362610306
# 0.2229893766204612
# 0.2208404511642549
# 0.2187765265737818
# 0.21679424063507918
# 0.2148903641267429
# 0.2130617955594011
# 0.21130555612326754
# 0.20961878483554022
# 0.20799873387975232
# 0.20644276412946977
# 0.20494834084905017
# ...

# %% [markdown]
# Print weight and biases and see if we have workied correctly

# %%
print(weights , biases)
# Out:
# [[ 2.00133927]
#  [-3.00479773]] 4.888873009280995

# %% [markdown]
# Plot output vs tragets

# %%
plt.plot(outputs, targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
